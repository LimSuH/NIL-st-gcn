# %% [markdown]
# skeleton(npy, pkl)파일 생성 전처리 코드 실행

# %%
# !conda activate pytorch
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.

# %%
# !pwd
# %cd /users/suhyeon/GitHub/NIL-st-gcn/st-gcn-master
# Out:
# /home/lab/miniconda3/envs/pytorch
# /users/suhyeon/GitHub/NIL-st-gcn/st-gcn-master

# %%
# !python tools/ksl_gendata.py --data data/KETI
# Out:
# preprocessing for train set.
# processing data:KETI_SL_0000012995 (1/100)
# processing data:KETI_SL_0000000839 (2/100)
# processing data:KETI_SL_0000024308 (3/100)
# processing data:KETI_SL_0000005029 (4/100)
# processing data:KETI_SL_0000030593 (5/100)
# processing data:KETI_SL_0000020537 (6/100)
# processing data:KETI_SL_0000015509 (7/100)
# processing data:KETI_SL_0000011738 (8/100)
# processing data:KETI_SL_0000014252 (9/100)
# processing data:KETI_SL_0000029336 (10/100)
# processing data:KETI_SL_0000006705 (11/100)
# processing data:KETI_SL_0000028079 (12/100)
# processing data:KETI_SL_0000002515 (13/100)
# processing data:KETI_SL_0000034364 (14/100)
# processing data:KETI_SL_0000004191 (15/100)
# processing data:KETI_SL_0000014253 (16/100)
# processing data:KETI_SL_0000020538 (17/100)
# processing data:KETI_SL_0000019281 (18/100)
# processing data:KETI_SL_0000031851 (19/100)
# processing data:KETI_SL_0000018024 (20/100)
# processing data:KETI_SL_0000001788 (21/100)
# ...

# %%
# !python main.py recognition -c config/st_gcn/KETI/train.yaml
# Out:
# [08.27.22|09:00:59 AM] Parameters:
# ...
